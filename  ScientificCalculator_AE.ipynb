# %%
import math
class Scientific_Calculator():
    def __init__(self,input1,input2):
        self.input1=input1
        self.input2=input2
        
    def addition(num1, num2):
        print("Addition", num1+num2)
            
    def subtraction(num1, num2):
        print("Subtraction: ", num1+num2)
            
    def multiplication(num1, num2):
        print("Multiplication: ", num1*num2)
            
    def division(num1, num2):
        print("Division: ", num1/num2)
        
    def square_root(num1):
        print("Square Root: ", math.sqrt(num1))
        
    def power(num1, num2):
        print("Power: ", num1**num2)
    
    def sine(num1):
        print("Power: ", math.sine(num1))    
    
    def Pi(num1):
        print("Pi: ", math.pi*(num1))
    
    def cosine(num1):
        print("cosine: ", math.cos(math.radians(num1)))

    def Log(num1, num2):
        print("Logarithm: ", math.log(num1, num2))
    
    def hyperbolic_cosine(num1):
        print("Hyperbolic Cosine:", math.cosh(num1))

    def tangent(num1):
        print("Tangent: ", math.tan(math.radians(num1)))
        
    def Exponent(num1):
        print("Exponent: ", math.exp(num1))
        
    def hyperbolic_tangent(num1):
        print("Hyperbolic Tangent: ", math.tanh(num1))
    
    def hyperbolic_sine(num1):
        print("Hyperbolic Sine: ", math.sinh(num1))
    
    def floor(num1):
        print("Floor: ", math.floor(num1))
    
    def exp(num1):
        print("exp: ", math.e**num1)
    def e(num1):
        print("e: ", math.e*num1)

    def ceil(num1):
        print("Ceiling: ", math.ceil(num1))      

while True:
    print("Select A Number: ")
    print("1: Addition: ")
    print("2: Subtraction: ")
    print("3: Multiplication: ")
    print("4: Division")
    print("5: Square Root: ") 
    print("6: Power: ")
    print("7: Sine: ") 
    print("8: Cosine: ")
    print("9: Pi: ")
    print("10: Logarithm: ")
    print("11: Hyperbolic Cosine: ")
    print("12: Tangent: ")
    print("13: Exponent: ")
    print("14: Hyperbolic Sine: ")
    print("15: Hyperbolic Tangent: ")
    print("16: Floor: ")
    print("17: exp: ")
    print("18: e: ")
    print("19: Ceiling: ")
    print("20: Exit")
    choice= int(input("Enter Your Choice (1 to 20): "))
    
    if choice==1:
        num1=int(input("Enter The 1st Number: "))
        num2=int(input("Enter The 2nd Number: "))
        Scientific_Calculator.addition(num1, num2)
        
    elif choice==2:
        num1=int(input("Enter The 1st Number: "))
        num2=int(input("Enter The 2nd Number: "))
        Scientific_Calculator.subtraction(num1, num2)
        
    elif choice==3:
        num1=int(input("Enter The 1st Number: "))
        num2=int(input("Enter The 2nd Number: "))
        Scientific_Calculator.multiplication(num1, num2)
        
    elif choice==4:
        num1=int(input("Enter The 1st Number: "))
        num2=int(input("Enter The 2nd Number: "))
        
        if num1==0:
            print("Infinity.")     
        else:
            Scientific_Calculator.division(num1, num2)
    
    elif choice==5:
        num1=int(input("Enter The 1st Number: "))
        Scientific_Calculator.square_root(num1)
        
    elif choice==6:
        num1=int(input("Enter The 1st Number: "))
        num2=int(input("Enter The 2nd Number: "))
        Scientific_Calculator.power(num1, num2)
    
    elif choice==7:
        num1=int(input("Enter The 1st Number: "))
        Scientific_Calculator.sine(num1)  
    
    elif choice==8:
        num1=int(input("Enter The 1st Number: "))
        Scientific_Calculator.cosine(num1)  
    
    elif choice==9:
        num1=int(input("Enter The 1st Number: "))
        Scientific_Calculator.Pi(num1)  

    elif choice==10:
        num1=int(input("Enter The 1st Number: "))
        num2=int(input("Enter The 2nd Number: "))
        Scientific_Calculator.Log(num1,num2)  

    elif choice==11:
        num1=int(input("Enter The 1st Number: "))
        Scientific_Calculator.hyperbolic_cosine(num1)  
        
    elif choice==12:
        num1=int(input("Enter The 1st Number: "))
        Scientific_Calculator.tangent(num1)  

    elif choice==13:
        num1=int(input("Enter The 1st Number: "))
        Scientific_Calculator.Exponent(num1)

    elif choice==15:
        num1=int(input("Enter The 1st Number: "))
        Scientific_Calculator.hyperbolic_tangent(num1)

    elif choice==14:
        num1=int(input("Enter The 1st Number: "))
        Scientific_Calculator.hyperbolic_sine(num1)
    elif choice==16:
        num1=int(input("Enter The 1st Number: "))
        Scientific_Calculator.floor(num1)
        
    elif choice==17:
        num1=int(input("Enter The 1st Number: "))
        Scientific_Calculator.exp(num1) 

    elif choice==18:
        num1=int(input("Enter The 1st Number: "))
        Scientific_Calculator.e(num1) 
        
    elif choice==19:
        num1=int(input("Enter The 1st Number: "))
        Scientific_Calculator.ceil(num1) 
    elif choice==20:
        break
    else:
        print("Invalid User Input")
# Out:
# Select A Number:
# 1: Addition:
# 2: Subtraction:
# 3: Multiplication:
# 4: Division
# 5: Square Root:
# 6: Power:
# 7: Sine:
# 8: Cosine:
# 9: Pi:
# 10: Logarithm:
# 11: Hyperbolic Cosine:
# 12: Tangent:
# 13: Exponent:
# 14: Hyperbolic Sine:
# 15: Hyperbolic Tangent:
# 16: Floor:
# 17: exp:
# 18: e:
# 19: Ceiling:
# 20: Exit
